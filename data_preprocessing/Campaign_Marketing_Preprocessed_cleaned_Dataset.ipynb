# %% [markdown]
# # Cleaning and Preprocessing of Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
from sklearn import preprocessing as pp
from matplotlib import pyplot as plt

# %%
print(os.listdir())
# Out:
# ['Campaign_Marketing_Preprocessed_cleaned_Dataset.ipynb', '.ipynb_checkpoints']

# %%
df = pd.read_csv("../Bank_marketing_cleaned_Data.csv")
df
# Out:
#       age           job  marital  education                            key  \
# 0      33        admin.   single   tertiary         33admin.singletertiary
# 1      29        admin.  married  secondary       29admin.marriedsecondary
# 2      62       retired  married    primary        62retiredmarriedprimary
# 3      62       retired  married    primary        62retiredmarriedprimary
# 4      40   blue-collar  married  secondary  40blue-collarmarriedsecondary
# ...   ...           ...      ...        ...                            ...
# 4127   31    management  married   tertiary    31managementmarriedtertiary
# 4128   35    technician  married  secondary   35technicianmarriedsecondary
# 4129   51   blue-collar  married    primary    51blue-collarmarriedprimary
# 4130   42  entrepreneur  married   tertiary  42entrepreneurmarriedtertiary
# 4131   49    technician  married   tertiary    49technicianmarriedtertiary
#
# ...

# %%
#Detecting NA,N/A and Null values

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# key          0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
y_array =df[['y']]
y_array
# Out:
#         y
# 0     yes
# 1      no
# 2     yes
# 3      no
# 4      no
# ...   ...
# 4127   no
# 4128  yes
# 4129   no
# 4130   no
# 4131  yes
#
# [4132 rows x 1 columns]

# %%
#Replacing 'yes' with 1 and 'no' with 0 in columb y

# %%
y_array = y_array['y'].replace({'no': 0, 'yes': 1})
y_array
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 4127    0
# 4128    1
# 4129    0
# 4130    0
# 4131    1
# Name: y, Length: 4132, dtype: int64

# %%
df['y'] = y_array
df
# Out:
#       age           job  marital  education                            key  \
# 0      33        admin.   single   tertiary         33admin.singletertiary
# 1      29        admin.  married  secondary       29admin.marriedsecondary
# 2      62       retired  married    primary        62retiredmarriedprimary
# 3      62       retired  married    primary        62retiredmarriedprimary
# 4      40   blue-collar  married  secondary  40blue-collarmarriedsecondary
# ...   ...           ...      ...        ...                            ...
# 4127   31    management  married   tertiary    31managementmarriedtertiary
# 4128   35    technician  married  secondary   35technicianmarriedsecondary
# 4129   51   blue-collar  married    primary    51blue-collarmarriedprimary
# 4130   42  entrepreneur  married   tertiary  42entrepreneurmarriedtertiary
# 4131   49    technician  married   tertiary    49technicianmarriedtertiary
#
# ...

# %%
#Replacing 'single' with 0 , 'married' with 1 and 'divorced' with 2 in columb marital

# %%
marital_array =df[['marital']]
marital_array = marital_array['marital'].replace({'single': 0,'married' : 1, 'divorced': 2})
df['marital'] = marital_array
df
# Out:
#       age           job  marital  education                            key  \
# 0      33        admin.        0   tertiary         33admin.singletertiary
# 1      29        admin.        1  secondary       29admin.marriedsecondary
# 2      62       retired        1    primary        62retiredmarriedprimary
# 3      62       retired        1    primary        62retiredmarriedprimary
# 4      40   blue-collar        1  secondary  40blue-collarmarriedsecondary
# ...   ...           ...      ...        ...                            ...
# 4127   31    management        1   tertiary    31managementmarriedtertiary
# 4128   35    technician        1  secondary   35technicianmarriedsecondary
# 4129   51   blue-collar        1    primary    51blue-collarmarriedprimary
# 4130   42  entrepreneur        1   tertiary  42entrepreneurmarriedtertiary
# 4131   49    technician        1   tertiary    49technicianmarriedtertiary
#
# ...

# %%
# Similarly replacing with binary values as above for columbs 'education','housing','loan','contact','poutcome'

# %%
y_array =df[['education']]
y_array = y_array['education'].replace({'primary': 0,'secondary' : 1, 'tertiary': 2})
df['education'] = y_array
df
# Out:
#       age           job  marital  education                            key  \
# 0      33        admin.        0          2         33admin.singletertiary
# 1      29        admin.        1          1       29admin.marriedsecondary
# 2      62       retired        1          0        62retiredmarriedprimary
# 3      62       retired        1          0        62retiredmarriedprimary
# 4      40   blue-collar        1          1  40blue-collarmarriedsecondary
# ...   ...           ...      ...        ...                            ...
# 4127   31    management        1          2    31managementmarriedtertiary
# 4128   35    technician        1          1   35technicianmarriedsecondary
# 4129   51   blue-collar        1          0    51blue-collarmarriedprimary
# 4130   42  entrepreneur        1          2  42entrepreneurmarriedtertiary
# 4131   49    technician        1          2    49technicianmarriedtertiary
#
# ...

# %%
y_array =df[['housing']]
y_array = y_array['housing'].replace({'yes': 1,'no' : 0})
df['housing'] = y_array
df
# Out:
#       age           job  marital  education                            key  \
# 0      33        admin.        0          2         33admin.singletertiary
# 1      29        admin.        1          1       29admin.marriedsecondary
# 2      62       retired        1          0        62retiredmarriedprimary
# 3      62       retired        1          0        62retiredmarriedprimary
# 4      40   blue-collar        1          1  40blue-collarmarriedsecondary
# ...   ...           ...      ...        ...                            ...
# 4127   31    management        1          2    31managementmarriedtertiary
# 4128   35    technician        1          1   35technicianmarriedsecondary
# 4129   51   blue-collar        1          0    51blue-collarmarriedprimary
# 4130   42  entrepreneur        1          2  42entrepreneurmarriedtertiary
# 4131   49    technician        1          2    49technicianmarriedtertiary
#
# ...

# %%
y_array =df[['loan']]
y_array = y_array['loan'].replace({'yes': 1,'no' : 0})
df['loan'] = y_array
df
# Out:
#       age           job  marital  education                            key  \
# 0      33        admin.        0          2         33admin.singletertiary
# 1      29        admin.        1          1       29admin.marriedsecondary
# 2      62       retired        1          0        62retiredmarriedprimary
# 3      62       retired        1          0        62retiredmarriedprimary
# 4      40   blue-collar        1          1  40blue-collarmarriedsecondary
# ...   ...           ...      ...        ...                            ...
# 4127   31    management        1          2    31managementmarriedtertiary
# 4128   35    technician        1          1   35technicianmarriedsecondary
# 4129   51   blue-collar        1          0    51blue-collarmarriedprimary
# 4130   42  entrepreneur        1          2  42entrepreneurmarriedtertiary
# 4131   49    technician        1          2    49technicianmarriedtertiary
#
# ...

# %%
y_array =df[['contact']]
y_array = y_array['contact'].replace({'cellular': 1,'telephone' : 0})
df['contact'] = y_array
df
# Out:
#       age           job  marital  education                            key  \
# 0      33        admin.        0          2         33admin.singletertiary
# 1      29        admin.        1          1       29admin.marriedsecondary
# 2      62       retired        1          0        62retiredmarriedprimary
# 3      62       retired        1          0        62retiredmarriedprimary
# 4      40   blue-collar        1          1  40blue-collarmarriedsecondary
# ...   ...           ...      ...        ...                            ...
# 4127   31    management        1          2    31managementmarriedtertiary
# 4128   35    technician        1          1   35technicianmarriedsecondary
# 4129   51   blue-collar        1          0    51blue-collarmarriedprimary
# 4130   42  entrepreneur        1          2  42entrepreneurmarriedtertiary
# 4131   49    technician        1          2    49technicianmarriedtertiary
#
# ...

# %%
y_array =df[['poutcome']]
y_array = y_array['poutcome'].replace({'success': 1,'failure' : 0,'other' : 2})
df['poutcome'] = y_array
df
# Out:
#       age           job  marital  education                            key  \
# 0      33        admin.        0          2         33admin.singletertiary
# 1      29        admin.        1          1       29admin.marriedsecondary
# 2      62       retired        1          0        62retiredmarriedprimary
# 3      62       retired        1          0        62retiredmarriedprimary
# 4      40   blue-collar        1          1  40blue-collarmarriedsecondary
# ...   ...           ...      ...        ...                            ...
# 4127   31    management        1          2    31managementmarriedtertiary
# 4128   35    technician        1          1   35technicianmarriedsecondary
# 4129   51   blue-collar        1          0    51blue-collarmarriedprimary
# 4130   42  entrepreneur        1          2  42entrepreneurmarriedtertiary
# 4131   49    technician        1          2    49technicianmarriedtertiary
#
# ...

# %%
balance_array = df[['balance']]
balance_array
# Out:
#       balance
# 0         272
# 1        6429
# 2        1742
# 3        3738
# 4         327
# ...       ...
# 4127     1224
# 4128      294
# 4129     1164
# 4130     1068
# 4131      523
#
# [4132 rows x 1 columns]

# %%
plt.hist(balance_array.balance,bins=80,rwidth = 0.7)
plt.xlabel('balance')
plt.ylabel('count')
plt.show()

# %%
balance_array.balance.min()
# Out:
# 1

# %%
balance_array.balance.max()
# Out:
# 81204

# %%
balance_array.balance.describe()
# Out:
# count     4132.000000
# mean      1816.119797
# std       3469.259219
# min          1.000000
# 25%        294.000000
# 50%        757.500000
# 75%       2037.000000
# max      81204.000000
# Name: balance, dtype: float64

# %%
#Using 3 standard deviation to remove the outliers

# %%
balance_array.balance.mean()
# Out:
# 1816.1197967086157

# %%
balance_array.balance.std()
# Out:
# 3469.2592192437255

# %%
upper_limit= balance_array.balance.mean() + 3*balance_array.balance.std()
upper_limit
# Out:
# 12223.897454439792

# %%
lower_limit = balance_array.balance.mean() - 3*balance_array.balance.std()
lower_limit
# Out:
# -8591.65786102256

# %%
balance_array[(balance_array.balance>upper_limit) | (balance_array.balance<lower_limit)]
# Out:
#       balance
# 222     20727
# 233     34230
# 254     17964
# 266     21522
# 346     12519
# 391     13107
# 401     12409
# 539     12857
# 586     22867
# 618     12607
# 655     18558
# 692     12569
# 792     29941
# 811     13014
# 845     23076
# 882     20585
# 890     12392
# 960     15834
# 982     15459
# 1124    16125
# 1139    17924
# 1157    81204
# 1326    27696
# 1418    17946
# 1431    20928
# 1635    15161
# 1673    17964
# 1979    27696
# 2103    26575
# 2327    23663
# 2332    52587
# 2378    15485
# 2398    13546
# 2426    23878
# 2434    13297
# 2738    81204
# 2837    29340
# 2886    27696
# 3117    12857
# 3133    16430
# 3222    19833
# 3297    22171
# 3457    26306
# 3488    13874
# 3541    16992
# 3595    22546
# 3732    12569
# 3757    16873
# 3853    12956
# 3905    37378
# 3907    12264
# 4060    29080
# 4091    17023

# %%
#Romoving these 53 outliers to balance the data

# %%
df=df[(df.balance<upper_limit) & (df.balance>lower_limit)]

# %%
plt.hist(df.balance,bins=50,rwidth = 0.7)
plt.xlabel('balance')
plt.ylabel('count')
plt.show()

# %%
df.y.describe()
# Out:
# count    4079.000000
# mean        0.360628
# std         0.480241
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: y, dtype: float64

# %%
#Using 3 standard deviation again to balance the dataset

# %%
df.balance.mean()
# Out:
# 1550.1110566315274

# %%
df.balance.std()
# Out:
# 2037.0172619123587

# %%
upper_limit= df.balance.mean() + 3*df.balance.std()
upper_limit
# Out:
# 7661.162842368603

# %%
lower_limit = df.balance.mean() - 3*df.balance.std()
lower_limit
# Out:
# -4560.940729105549

# %%
df[(df.balance>upper_limit) | (df.balance<lower_limit)]
# Out:
#       age            job  marital  education                             key  \
# 6      32     technician        1          2     32technicianmarriedtertiary
# 19     38       services        1          1      38servicesmarriedsecondary
# 20     27     technician        0          2      27techniciansingletertiary
# 98     60         admin.        2          1       60admin.divorcedsecondary
# 126    44     technician        1          1    44technicianmarriedsecondary
# ...   ...            ...      ...        ...                             ...
# 4015   37     management        1          2     37managementmarriedtertiary
# 4061   37  self-employed        1          2  37self-employedmarriedtertiary
# 4094   29    blue-collar        1          0     29blue-collarmarriedprimary
# 4095   45     technician        2          2    45techniciandivorcedtertiary
# 4125   57     management        1          2     57managementmarriedtertiary
#
# ...

# %%
df=df[(df.balance<upper_limit) & (df.balance>lower_limit)]
df
# Out:
#       age           job  marital  education                            key  \
# 0      33        admin.        0          2         33admin.singletertiary
# 1      29        admin.        1          1       29admin.marriedsecondary
# 2      62       retired        1          0        62retiredmarriedprimary
# 3      62       retired        1          0        62retiredmarriedprimary
# 4      40   blue-collar        1          1  40blue-collarmarriedsecondary
# ...   ...           ...      ...        ...                            ...
# 4127   31    management        1          2    31managementmarriedtertiary
# 4128   35    technician        1          1   35technicianmarriedsecondary
# 4129   51   blue-collar        1          0    51blue-collarmarriedprimary
# 4130   42  entrepreneur        1          2  42entrepreneurmarriedtertiary
# 4131   49    technician        1          2    49technicianmarriedtertiary
#
# ...

# %%
plt.hist(df.balance,bins=50,rwidth = 0.7)
plt.xlabel('balance')
plt.ylabel('count')
plt.show()

# %%
df.y.describe()
# Out:
# count    3963.000000
# mean        0.357810
# std         0.479416
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: y, dtype: float64

# %%
from pathlib import Path  
filepath = Path('../bank_marketing_processed_data.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df.to_csv(filepath)
